# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# Going to Velcro search page in Home Depot
options = webdriver.ChromeOptions()
options.add_argument("--headless")
browser = webdriver.Chrome(chrome_options=options)
#url = 'https://www.homedepot.com'
url = 'https://www.homedepot.com/s/velcro?NCNI-5'
browser.get(url)

#browser.find_element_by_id('headerSearch').send_keys('velcro')
#browser.find_element_by_id('headerSearchButton').click()

data = []

# %%
hasNext = True

while hasNext:

    # Get all HTML in document and assign it to BeautifulSoup variable
    innerHTML = browser.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(innerHTML,"lxml")
    
    # Finds all of the individual products
    items = soup.find_all('div', 'pod-inner')
    
    # Get all product information on this page
    for index in range(len(items)):
        item = items[index]
        item_img = item.find('img')['src']
        item_name = (item.find('div',{'data-podaction' : 'product name'}).text)
        data += [{'product-image': item_img,
                  'product-name' : item_name.replace('\n', '').replace('\t','')}]

    # If there is a next page go to the next page
    try:
        nextLink = soup.find("a", {"title" : "Next"})
        browser.get('http://homedepot.com/' + nextLink['href'])
    except:
        hasNext = False

# %%
for i in range(len(data)):
    print(i+1)
    print(data[i]['product-image'])
    print(data[i]['product-name'])
    
browser.quit()
# Out:
# 1
# https://images.homedepot-static.com/productImages/ee9a1e2b-6a48-404c-b307-fb7d327be35c/svn/velcro-brand-hook-loop-90440acs-64_400_compressed.jpg
# VELCRO Brand     3 ft. x 2 in. Velstrap Straps (2-Pack)
# 2
# https://images.homedepot-static.com/productImages/551f6e5e-3a92-4f34-b4c7-54eafd2239c9/svn/velcro-brand-hook-loop-90199-64_400_compressed.jpg
# VELCRO Brand     4 in. x 2 in. Industrial Strength Strips (2-Pack)
# 3
# https://images.homedepot-static.com/productImages/59c4ad75-e74f-4444-a403-47d0245f0282/svn/velcro-brand-hook-loop-90593-64_400_compressed.jpg
# VELCRO Brand     4 ft. x 2 in. Industrial Strength Tape
# 4
# https://images.homedepot-static.com/productImages/a043d237-8c73-4431-b273-27d570604d1f/svn/velcro-brand-hook-loop-90924hd-64_400_compressed.jpg
# VELCRO Brand     8 in. x 1/2 in. Reusable Ties (50-Pack)
# 5
# https://images.homedepot-static.com/productImages/8fe526c1-92fe-453e-b09d-e0a98839a0ba/svn/velcro-brand-hook-loop-90197-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 2 in. Industrial Strength Tape
# 6
# https://images.homedepot-static.com/productImages/ca1d2ec9-bd4b-41a8-ba16-09e27e3ee61f/svn/velcro-brand-hook-loop-90340-64_400_compressed.jpg
# VELCRO Brand     12 ft. x 3/4 in. One-Wrap Strap
# 7
# https://images.homedepot-static.com/productImages/6e9a6e99-9708-4467-aaab-6e3618b6bcb7/svn/velcro-brand-hook-loop-91843-64_400_compressed.jpg
# VELCRO Brand     10 ft. x 1 in. Black Industrial Strength Extreme Tape
# 8
# https://images.homedepot-static.com/productImages/c2c49d11-8a66-42ca-b403-38c470255f65/svn/velcro-brand-hook-loop-90438acs-64_400_compressed.jpg
# VELCRO Brand     8 in. x 1/2 in. Multi-Color One-Wrap Straps (5-Pack)
# 9
# https://images.homedepot-static.com/productImages/f935a892-ab27-4a9f-8dc4-684ff3c238a0/svn/velcro-brand-hook-loop-90086-64_400_compressed.jpg
# VELCRO Brand     5 ft. x 3/4 in. Sticky Back Tape
# 10
# https://images.homedepot-static.com/productImages/4af6b9e3-69d2-4dfe-bdac-1c3bda1a4ad5/svn/velcro-brand-hook-loop-90276b-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 3/4 in. Sticky Back Tape
# 11
# https://images.homedepot-static.com/productImages/ac3085ad-505f-4461-84da-3f96806fb7ca/svn/velcro-brand-hook-loop-90700-64_400_compressed.jpg
# VELCRO Brand     23 in. x 7/8 in. 1-Wrap Straps (3-Pack)
# 12
# https://images.homedepot-static.com/productImages/2348ec7a-41e5-4119-abf3-e1433cd00511/svn/velcro-brand-hook-loop-91878-64_400_compressed.jpg
# VELCRO Brand     24 in. x 3/4 in. Sticky Back for Fabrics Tape Black
# 13
# https://images.homedepot-static.com/productImages/a17c47dc-4645-4d27-961d-469ccd2fe2b1/svn/velcro-brand-hook-loop-91793-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 2 in. Industrial Strength Tape in White
# 14
# https://images.homedepot-static.com/productImages/37ac9f0c-4632-43f0-9518-1a99cdb59a13/svn/velcro-brand-hook-loop-90075-64_400_compressed.jpg
# VELCRO Brand     3-1/2 in. x 3/4 in. Sticky Back Strips (4-Pack)
# 15
# https://images.homedepot-static.com/productImages/b077f3ec-ecac-498f-b8ad-260e9d97472d/svn/velcro-brand-hook-loop-90198-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 2 in. Industrial Strength Tape
# 16
# https://images.homedepot-static.com/productImages/de920402-5af7-4c67-b6d5-556c089c28ed/svn/velcro-brand-hook-loop-90200-64_400_compressed.jpg
# VELCRO Brand     4 in. x 2 in. Industrial Strength Strips (2-Pack)
# 17
# https://images.homedepot-static.com/productImages/7f399528-a453-4157-9938-179f9c762c19/svn/velcro-brand-hook-loop-90595-64_400_compressed.jpg
# VELCRO Brand     4 ft. x 2 in. Industrial Strength Tape
# 18
# https://images.homedepot-static.com/productImages/036051d2-669d-4502-b815-3dad7036fbae/svn/velcro-brand-hook-loop-91372-64_400_compressed.jpg
# VELCRO Brand     30 ft. x 1-1/2 in. One-Wrap Strap
# 19
# https://images.homedepot-static.com/productImages/ff9e5848-60e9-41bd-9f9e-246437a32130/svn/velcro-brand-hook-loop-91365-64_400_compressed.jpg
# VELCRO Brand     10 ft. x 1 in. Extreme Titanium Tape
# 20
# https://images.homedepot-static.com/productImages/b74bad8d-88a8-42db-9d24-8bb4934d2d21/svn/velcro-brand-hook-loop-90076-64_400_compressed.jpg
# VELCRO Brand     3-1/2 in. x 3/4 in. Sticky Back Strips (4-Pack)
# 21
# https://images.homedepot-static.com/productImages/045080d5-7104-4d5f-9bf0-441c4104e02f/svn/velcro-brand-hook-loop-91614-64_400_compressed.jpg
# VELCRO Brand     3/8 in. Thin Clear Fasteners (56-Pack)
# 22
# https://images.homedepot-static.com/productImages/32c67524-b1f7-4881-a0fb-274a9f2867dc/svn/velcro-brand-hook-loop-91100-64_400_compressed.jpg
# VELCRO Brand     10 ft. x 1 in. Ultra-Mate Tape
# 23
# https://images.homedepot-static.com/productImages/ca89c1f1-a724-423d-8b0e-9f34423ec8b1/svn/velcro-brand-hook-loop-90087-64_400_compressed.jpg
# VELCRO Brand     5 ft. x 3/4 in. Sticky Back Tape
# 24
# https://images.homedepot-static.com/productImages/4ecb7e99-c55a-41ed-a16d-6a77e40ae2f6/svn/velcro-brand-office-fasteners-95179-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 3/4 in. Removable Mounting Tape
# 25
# https://images.homedepot-static.com/productImages/045080d5-7104-4d5f-9bf0-441c4104e02f/svn/velcro-brand-hook-loop-91614-64_400_compressed.jpg
# VELCRO Brand     3/8 in. Thin Clear Fasteners (56-Pack)
# 26
# https://images.homedepot-static.com/productImages/32c67524-b1f7-4881-a0fb-274a9f2867dc/svn/velcro-brand-hook-loop-91100-64_400_compressed.jpg
# VELCRO Brand     10 ft. x 1 in. Ultra-Mate Tape
# 27
# https://images.homedepot-static.com/productImages/ca89c1f1-a724-423d-8b0e-9f34423ec8b1/svn/velcro-brand-hook-loop-90087-64_400_compressed.jpg
# VELCRO Brand     5 ft. x 3/4 in. Sticky Back Tape
# 28
# https://images.homedepot-static.com/productImages/4ecb7e99-c55a-41ed-a16d-6a77e40ae2f6/svn/velcro-brand-office-fasteners-95179-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 3/4 in. Removable Mounting Tape
# 29
# https://images.homedepot-static.com/productImages/7c7dd2d4-6fb6-426c-a517-c35e5df6085e/svn/velcro-brand-picture-mirror-hanging-95184-64_400_compressed.jpg
# VELCRO Brand     HANGables Removable Wall Fasteners 3/4 in. Squares (16-Count)
# 30
# https://images.homedepot-static.com/productImages/175eecfd-7348-4304-b08e-7f9fe6aced18/svn/velcro-brand-hook-loop-90073-64_400_compressed.jpg
# VELCRO Brand     7/8 in. Sticky Back Squares (12-Pack)
# 31
# https://images.homedepot-static.com/productImages/497c54db-c267-41f4-b2e7-583fa21fa84d/svn/velcro-brand-hook-loop-91844-64_400_compressed.jpg
# VELCRO Brand     4 ft. x 1 in. Titanium Industrial Strength Extreme Tape
# 32
# https://images.homedepot-static.com/productImages/ef867a12-0ef2-43d2-8981-41bf4ebe98b1/svn/velcro-brand-hook-loop-90482-64_400_compressed.jpg
# VELCRO Brand     6 ft. x 2 in. All Purpose Strap with Handle Black
# 33
# https://images.homedepot-static.com/productImages/53d260fc-94ad-4d9b-9dea-b92c6c1a5174/svn/velcro-brand-picture-mirror-hanging-95183-64_400_compressed.jpg
# VELCRO Brand     HANGables Removable Wall Fasteners 3 in. x 1-3/4 in. Strips (4-Count)
# 34
# https://images.homedepot-static.com/productImages/7b7f999e-4f73-4193-a1dd-bde319ddc5b4/svn/velcro-brand-hook-loop-90277b-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 3/4 in. Sticky Back Tape
# 35
# https://images.homedepot-static.com/productImages/de82b172-d8f0-458b-8d76-1c9319393b3b/svn/velcro-brand-hook-loop-90812-64_400_compressed.jpg
# VELCRO Brand     4 in. x 1 in. Titanium Strips (10-Pack)
# 36
# https://images.homedepot-static.com/productImages/145e8e5d-786f-4d72-ab01-0c5aed630597/svn/velcro-brand-hook-loop-91839-64_400_compressed.jpg
# VELCRO Brand     4 in. x 2 in. Industrial Strength Extreme Strip, Black
# 37
# https://images.homedepot-static.com/productImages/b588b230-f4a8-41ea-8d96-5edb73542d9b/svn/velcro-brand-hook-loop-90072-64_400_compressed.jpg
# VELCRO Brand     7/8 in. Sticky Back Squares (12-Pack)
# 38
# https://images.homedepot-static.com/productImages/fd126123-55e6-49cd-a2f9-03237394294a/svn/velcro-brand-picture-mirror-hanging-95185-64_400_compressed.jpg
# VELCRO Brand     HANGables Removable Wall Fasteners 1-3/4 in. x 3/4 in. Strips (8-Count)
# 39
# https://images.homedepot-static.com/productImages/758bf59e-bf22-41b5-84bd-645e92c9ec8f/svn/velcro-brand-hook-loop-91442-64_400_compressed.jpg
# VELCRO Brand     8 in. x 1/2 in. One-Wrap Roll Fire Retardant, Cranberry (10-Count)
# 40
# https://images.homedepot-static.com/productImages/e5947e74-738e-4ad8-b3a4-c9a451760ec2/svn/velcro-brand-hook-loop-91792-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 2 in. Industrial Strength Tape in Black
# 41
# https://images.homedepot-static.com/productImages/21ec8a1d-d287-42c5-a5e3-949f2d756097/svn/velcro-brand-picture-mirror-hanging-95182-64_400_compressed.jpg
# VELCRO Brand     HANGables Removable Wall Fasteners 3 in. x 1-3/4 in. Corners (4-Count)
# 42
# https://images.homedepot-static.com/productImages/f84a96ba-6399-4086-b456-adae8570b0b2/svn/velcro-brand-office-fasteners-95178-64_400_compressed.jpg
# VELCRO Brand     18 in. x 3/4 in. Removable Mounting Tape
# 43
# https://images.homedepot-static.com/productImages/e8235f16-c1fa-4960-a540-fea4a73f9900/svn/velcro-brand-hook-loop-90726-64_400_compressed.jpg
# VELCRO Brand     8 in x 1/2 in. One-Wrap Ties Black (5-Count)
# 44
# https://images.homedepot-static.com/productImages/6bc4db87-e77a-4ecf-8dfc-560a3d424497/svn/velcro-brand-hook-loop-90363-64_400_compressed.jpg
# VELCRO Brand     1-7/8 in. Industrial Strength Coin, White
# 45
# https://images.homedepot-static.com/productImages/6b90086c-046e-4696-a522-9e32c0b86515/svn/velcro-brand-hook-loop-90476acs-64_400_compressed.jpg
# VELCRO Brand     15 in. x 1/2 in. One-Wrap Straps (6-Pack)
# 46
# https://images.homedepot-static.com/productImages/ca5c77f5-20a7-482f-b2ba-3463c11ac7d5/svn/velcro-brand-hook-loop-90099-64_400_compressed.jpg
# VELCRO Brand     18 in. x 1 in. Marine Grade Strap, Blue (2-Count)
# 47
# https://images.homedepot-static.com/productImages/ac032c7b-6259-44d4-a411-2e583932d7d2/svn/velcro-brand-hook-loop-91050-64_400_compressed.jpg
# VELCRO Brand     3 ft. x 1 in. Ultra-Mate Tape
# 48
# https://images.homedepot-static.com/productImages/08e68b45-389c-4bab-8d6a-8b3256ea28cf/svn/velcro-brand-hook-loop-90362-64_400_compressed.jpg
# VELCRO Brand     1-7/8 in. Industrial Strength Black Coins (4-Pack)
# 49
# https://images.homedepot-static.com/productImages/30408125-a77f-4ca2-af0e-8f7e703fa507/svn/velcro-brand-hook-loop-91373-64_400_compressed.jpg
# VELCRO Brand     4 in. x 2 in. Industrial Strength Extreme Strip, Titanium
# 50
# https://images.homedepot-static.com/productImages/0f602b82-1fc9-415b-9ac0-920f2baf3e9e/svn/velcro-brand-office-fasteners-95189-64_400_compressed.jpg
# VELCRO Brand     3-1/2in x 3/4in. Removable Mounting Strips (4-Count)
# 51
# https://images.homedepot-static.com/productImages/d84d6390-0675-4136-931f-fe522ac88f80/svn/velcro-brand-hook-loop-91757-64_400_compressed.jpg
# VELCRO Brand     4 ft. x 1 in. All Purpose Multi-Cam Strap (2-Pack)
# 52
# https://images.homedepot-static.com/productImages/f4214d64-0848-4bab-a297-3837e830407f/svn/velcro-brand-hook-loop-91000-64_400_compressed.jpg
# VELCRO Brand     1 in. x 3/4 in. Industrial Strength Low Profile Spot, Black (10-Pack)
# 53
# https://images.homedepot-static.com/productImages/ed09a405-0c33-429a-8a84-d1086119bc9d/svn/velcro-brand-hook-loop-91845-64_400_compressed.jpg
# VELCRO Brand     4 ft. x 1 in. Black Industrial Strength Extreme Tape
# 54
# https://images.homedepot-static.com/productImages/faca17ad-aa23-430c-ad48-a10e692d65c1/svn/velcro-brand-office-fasteners-95188-64_400_compressed.jpg
# VELCRO Brand     3/8 in. Removable Mounting Circles (56-Count)
# 55
# https://images.homedepot-static.com/productImages/26e8dcf8-853e-4d01-ba0b-99555e0c2258/svn/velcro-brand-hook-loop-91758-64_400_compressed.jpg
# VELCRO Brand     6 ft. x 1 1/2 in. All Purpose Multi-Cam Strap
# 56
# https://images.homedepot-static.com/productImages/b035c172-9b7d-435d-a071-670209b46581/svn/velcro-brand-hook-loop-vel-30118-usa-64_400_compressed.jpg
# VELCRO Brand     20 ft. x 1-1/2 in. Industrial Strength Tape in Black
# 57
# https://images.homedepot-static.com/productImages/36b0337e-00e6-4e19-8194-36d3979dab1c/svn/velcro-brand-hook-loop-vel-30119-usa-64_400_compressed.jpg
# VELCRO Brand     20 ft. x 1-1/2 in. Industrial Strength Tape in White
# 58
# https://images.homedepot-static.com/productImages/c6a2a502-69e9-46a5-9c68-8a27a9d606ad/svn/velcro-brand-hook-loop-91597-64_400_compressed.jpg
# VELCRO Brand     5 in. x 1/4 in. One-Wrap Ties Bright, Green (10-Pack)
# 59
# https://images.homedepot-static.com/productImages/22f10ee1-5f69-4cda-84e4-3fb305555b69/svn/velcro-brand-hook-loop-91808-64_400_compressed.jpg
# VELCRO Brand     12 ft. x 3/4 in. 1-Wrap Ties, White
# 60
# https://images.homedepot-static.com/productImages/ee903145-b7fc-4b52-9b9d-f89dbee48169/svn/velcro-brand-hook-loop-91325-64_400_compressed.jpg
# VELCRO Brand     15 ft. x 3/4 in. Sticky Back Tape
# 61
# https://images.homedepot-static.com/productImages/a04bcc89-b47a-41de-be2b-a5dba7b67489/svn/velcro-brand-hook-loop-91873-64_400_compressed.jpg
# VELCRO Brand     Sticky Back for Fabrics Ovals, White (8-Count)
# 62
# https://images.homedepot-static.com/productImages/5b762b5b-6195-41de-b3c0-2219ade66b15/svn/velcro-brand-blocks-building-sets-blocks-70191-64_400_compressed.jpg
# VELCRO Brand Blocks     Jumbo Robot Construction Set
# 63
# https://images.homedepot-static.com/productImages/b8701d25-602f-4ae0-8051-d8c9770e6b09/svn/velcro-brand-hook-loop-91302-64_400_compressed.jpg
# VELCRO Brand     5/8 in. Sticky Back Coin Sets (75-Pack)
# 64
# https://images.homedepot-static.com/productImages/f120b58e-5606-40c1-b017-47529e57c335/svn/velcro-brand-blocks-building-sets-blocks-70157-64_400_compressed.jpg
# VELCRO Brand Blocks     Formula Race Car Construction Set
# 65
# https://images.homedepot-static.com/productImages/e2f1541e-af46-42e6-9860-c7d78a0ea4d7/svn/velcro-brand-blocks-building-sets-blocks-70189-64_400_compressed.jpg
# VELCRO Brand Blocks     Robot Construction Set
# 66
# https://images.homedepot-static.com/productImages/78dc782a-0e3e-4ae9-88f2-0303b9049ce1/svn/velcro-brand-hook-loop-90078-64_400_compressed.jpg
# VELCRO Brand     18 in. x 3/4 in. Sticky Back Tape
# 67
# https://images.homedepot-static.com/productImages/e0a0d04a-4f51-4659-be13-8cbaa9ee353a/svn/velcro-brand-blocks-building-sets-blocks-70183-64_400_compressed.jpg
# VELCRO Brand Blocks     Construction Set (42-Piece)
# 68
# https://images.homedepot-static.com/productImages/204c3a29-a018-47c0-baf9-bf56bea65e08/svn/clear-velcro-brand-garment-bags-93058-64_400_compressed.jpg
# VELCRO Brand     PRESS-LOK Reusable Bags Variety Pack (3-Count)
# 69
# https://images.homedepot-static.com/productImages/180d7f37-31c4-499d-9efd-be5713d70eeb/svn/velcro-brand-hook-loop-90079-64_400_compressed.jpg
# VELCRO Brand     18 in. x 3/4 in. Sticky Back Tape
# 70
# https://images.homedepot-static.com/productImages/c2ff43e3-7c87-4962-b453-79dbb6ed4c90/svn/velcro-brand-blocks-building-sets-blocks-70164-64_400_compressed.jpg
# VELCRO Brand Blocks     Monster Truck Construction Set
# 71
# https://images.homedepot-static.com/productImages/a5cfee3c-53e1-4eb8-b86f-ac4b1aa98ff5/svn/velcro-brand-blocks-building-sets-blocks-70188-64_400_compressed.jpg
# VELCRO Brand Blocks     Construction Set (80-Piece)
# 72
# https://images.homedepot-static.com/productImages/ff486b20-f45b-4f5e-8e1a-4b707b11dae7/svn/velcro-brand-blocks-building-sets-blocks-70193-64_400_compressed.jpg
# VELCRO Brand Blocks     Triceratops Construction Set
# 73
# https://images.homedepot-static.com/productImages/0965edb2-9aca-45d2-bf2e-5d31b905ac71/svn/velcro-brand-hook-loop-90472-64_400_compressed.jpg
# VELCRO Brand     11 in. x 1/2 in. 1-Wrap Ties in Green (6-Count)
# 74
# https://images.homedepot-static.com/productImages/b883d848-a7ec-4e86-a9e5-79b4dfafba3d/svn/velcro-brand-blocks-building-sets-blocks-70194-64_400_compressed.jpg
# VELCRO Brand Blocks     Stegosaurus Construction Set
# 75
# https://images.homedepot-static.com/productImages/7c0e3115-305b-4824-bbfb-b1dd9f70b3c4/svn/velcro-brand-picture-mirror-hanging-95192-64_400_compressed.jpg
# VELCRO Brand     HANGables Removable Wall Fasteners 2-1/2 in. Curves (4-Count)
# 76
# https://images.homedepot-static.com/productImages/a274b89a-eccc-4c1d-abde-46c5c2568d9f/svn/velcro-brand-hook-loop-91595-64_400_compressed.jpg
# VELCRO Brand     5 in. x 1/4 in. One-Wrap Ties Bright, Blue (10-Pack)
# 77
# https://images.homedepot-static.com/productImages/b58d5325-0273-4542-859b-d56e2b14027d/svn/velcro-brand-hook-loop-91330-64_400_compressed.jpg
# VELCRO Brand     7/8 in. Sticky Back Square Sets (12-Pack)
# 78
# https://images.homedepot-static.com/productImages/4387a4d6-70e3-493e-8516-f9bc05923db4/svn/velcro-brand-blocks-building-sets-blocks-70163-64_400_compressed.jpg
# VELCRO Brand Blocks     Race Car Construction Set
# 79
# https://images.homedepot-static.com/productImages/a9bae3a5-1834-4017-a82e-5dddb32f73eb/svn/velcro-brand-blocks-building-sets-blocks-70190-64_400_compressed.jpg
# VELCRO Brand Blocks     Doggy Robot Construction Set
# 80
# https://images.homedepot-static.com/productImages/bc93ae1a-5418-409c-b01f-f62054d6d58a/svn/velcro-brand-blocks-building-sets-blocks-70187-64_400_compressed.jpg
# VELCRO Brand Blocks     Construction Set (60-Piece)
# 81
# https://images.homedepot-static.com/productImages/22c5b08e-22a1-487c-8861-849efaf8ef36/svn/velcro-brand-blocks-building-sets-blocks-70192-64_400_compressed.jpg
# VELCRO Brand Blocks     T-Rex Construction Set
# 82
# https://images.homedepot-static.com/productImages/32f04252-3e0c-426f-85ab-93e3288b4a6e/svn/velcro-brand-hook-loop-91879-64_400_compressed.jpg
# VELCRO Brand     Sticky Back for Fabrics Ovals, Black (8-Count)
# 83
# https://images.homedepot-static.com/productImages/58e0faf1-6ee4-42de-8ed5-6c411552eaa0/svn/velcro-brand-hook-loop-91299-64_400_compressed.jpg
# VELCRO Brand     5 ft. x 3/4 in. Sticky Back Tape
# 84
# https://images.homedepot-static.com/productImages/ef3f4ffc-2925-4c72-8dbf-9577ee9db7ac/svn/clear-velcro-brand-garment-bags-95175-64_400_compressed.jpg
# VELCRO Brand     PRESS-LOK Small Reusable Bags (2-Count)
# 85
# https://images.homedepot-static.com/productImages/6b73f82e-2ef4-4ec8-b158-fe8fc4c79e9a/svn/clear-velcro-brand-garment-bags-95173-64_400_compressed.jpg
# VELCRO Brand     PRESS-LOK X-Small Reusable Bags (2-Count)
# 86
# https://images.homedepot-static.com/productImages/52983b09-ebaf-4d30-ac46-b342d2f76e01/svn/velcro-brand-hook-loop-91596-64_400_compressed.jpg
# VELCRO Brand     5 in. x 1/4 in. One-Wrap Tie One-Bright, Orange
# 87
# https://images.homedepot-static.com/productImages/ab66308b-d2c9-4696-b441-a4c4b66286d1/svn/velcro-brand-picture-mirror-hanging-vel-30107-usa-64_400_compressed.jpg
# VELCRO Brand     Hangables Removable Small Hook in White (4-Count)
# 88
# https://images.homedepot-static.com/productImages/4a90443f-c7cc-432d-ad11-4ba99ca4d814/svn/velcro-brand-picture-mirror-hanging-vel-30103-usa-64_400_compressed.jpg
# VELCRO Brand     Hangables Removable Micro Hook in White (8-Count)
# 89
# https://images.homedepot-static.com/productImages/d5f2cd72-de81-423c-8bc5-00fbad9da014/svn/velcro-brand-picture-mirror-hanging-vel-30109-usa-64_400_compressed.jpg
# VELCRO Brand     Hangables Removable Small Hook in Black (2-Count)
# 90
# https://images.homedepot-static.com/productImages/e26cc11d-674f-4589-9230-23e239636ec2/svn/velcro-brand-picture-mirror-hanging-vel-30102-usa-64_400_compressed.jpg
# VELCRO Brand     Hangables Removable Micro Hook in White (4-Count)
# 91
# https://images.homedepot-static.com/productImages/95f8a492-53bd-4e36-9043-cd867b57d4a0/svn/clear-velcro-brand-garment-bags-95177-64_400_compressed.jpg
# VELCRO Brand     PRESS-LOK Medium Reusable Bags (2-Count)
# 92
# https://images.homedepot-static.com/productImages/ac225af1-4bba-43d1-b1a6-551f2ccefacb/svn/velcro-brand-picture-mirror-hanging-vel-30104-usa-64_400_compressed.jpg
# VELCRO Brand     Hangables Removable Micro Hook in Aqua (4-Count)
# 93
# https://images.homedepot-static.com/productImages/efc82b54-3c5e-414e-ad17-c6824aea18d2/svn/velcro-brand-picture-mirror-hanging-vel-30105-usa-64_400_compressed.jpg
# VELCRO Brand     Hangables Removable Micro Hook in Black (4-Count)
# 94
# https://images.homedepot-static.com/productImages/d3ee21ea-e8be-47cb-b9c3-4181a09dc66c/svn/velcro-brand-picture-mirror-hanging-vel-30108-usa-64_400_compressed.jpg
# VELCRO Brand     Hangables Removable Small Hook in Aqua (2-Count)
# 95
# https://images.homedepot-static.com/productImages/b1bfa7bb-7836-4787-ae5c-efb1a39d75b6/svn/velcro-brand-picture-mirror-hanging-vel-30106-usa-64_400_compressed.jpg
# VELCRO Brand     Hangables Removable Small Hook in White (2-Count)
# 96
# https://images.homedepot-static.com/productImages/ccf4a8f8-c84e-4723-b123-d1567c5b3feb/svn/velcro-brand-office-fasteners-95191-64_400_compressed.jpg
# VELCRO Brand     1-3/4 in. x 3/4 in. Removable Mounting Strips (4-Count)
# 97
# https://images.homedepot-static.com/productImages/1eb22ef5-481c-4951-a412-47b94827397c/svn/velcro-brand-office-fasteners-95190-64_400_compressed.jpg
# VELCRO Brand     3/4 in. Removable Mounting Squares (8-Count)
# 98
# https://images.homedepot-static.com/productImages/59a1d280-e723-40ed-a406-d1ba7af09aca/svn/leviton-voice-data-cable-43108-8-64_400_compressed.jpg
# Leviton     Cable Management Solutions 8 in. Re-Closeable VELCRO Brand Tie Wrap, Black (25-Pack)
# 99
# https://images.homedepot-static.com/productImages/539fcd58-6f4c-496b-b1ab-5ee00db4e73d/svn/leviton-accessories-4s115-75e-64_400_compressed.jpg
# Leviton     Cable Management Solutions 75 ft. VELCRO Brand Bulk Roll, Black
# 100
# https://images.homedepot-static.com/productImages/1873e709-38e5-4505-abbe-f0b5b5cd18be/svn/leviton-accessories-43115-75y-64_400_compressed.jpg
# Leviton     Cable Management Solutions 75 ft. VELCRO Brand Bulk Roll, Yellow
# 101
# https://images.homedepot-static.com/productImages/2601385b-17f6-4425-a6da-44b4d1943c08/svn/bon-concrete-specialty-tools-24-126-64_400_compressed.jpg
# Bon     Replacement Velcro Strap for Bon's 6-Piece Paver Screed Set
# 102
# https://images.homedepot-static.com/productImages/b6af3a20-e0c0-4658-8f4f-38b2047a0539/svn/leviton-accessories-43115-600-64_400_compressed.jpg
# Leviton     Cable Management Solutions 600 ft. VELCRO Brand Bulk Roll, Black
# 103
# https://images.homedepot-static.com/productImages/7aef9206-774a-4693-9cde-3ea4f604a5cd/svn/leviton-accessories-43115-75p-64_400_compressed.jpg
# Leviton     Cable Management Solutions 75 ft. VELCRO Brand Bulk Roll, Maroon
# 104
# https://images.homedepot-static.com/productImages/93c13a80-7366-476c-8173-500b21a7d66e/svn/leviton-accessories-43115-75o-64_400_compressed.jpg
# Leviton     Cable Management Solutions 75 ft. VELCRO Brand Bulk Roll, Orange
# 105
# https://images.homedepot-static.com/productImages/8dd7dd1a-303f-4f4c-b09d-1bcd454df4fa/svn/leviton-accessories-43115-75l-64_400_compressed.jpg
# Leviton     Cable Management Solutions 75 ft. VELCRO Brand Bulk Roll, Blue
# 106
# https://images.homedepot-static.com/productImages/43cf03ca-f5b7-4306-bf87-6b142d45e3ef/svn/velcro-brand-blocks-building-sets-blocks-70158-64_400_compressed.jpg
# VELCRO Brand Blocks     Baja Buggy Construction Set
